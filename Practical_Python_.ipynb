# %% [markdown]
# **Question 1 : What is the difference between multithreading and multiprocessing?**

# %% [markdown]
# -a thread is a smaller unit of execution inside a process while a process is simply running a program
#
# -one process can have multiple threads but a sinple process runs and has its own memory
#
# - one thread can accidentally affect another because they share memory while a process can use multiple CPU cores affectively
#
# -multithreading communicates faster than multi-processing
#
# -threads use less memory compared to processes
#
# -threads work best when a program spends a lotof time waiting e.g downloading files while processes are best when the program spends a lot of time calculating e.g image processing
#
# -threads use I/O-bound tasks and processes use CPU-bound taks.

# %% [markdown]
# **Question 2: What are the challenges associated with memory management in Python?**

# %% [markdown]
# Memory Management is how python allocates, uses and frees memory while programm is running.
#
# 1) High Memory Usage
#
# - python objects take up more than other lower level languages such as c,c++
#
# 2) Memory Leaks
#
# - python has garbage collection, yet leasks still occur ig objects are accidentally kept
#
# - if you keep adding data, memory usage keeps growing
#
# 3) Garbage Collection Overhead
#
# - python frees unused memory, but also uses CPU time, which slightly reduces performance while checking
#
# 4) Circular References
#
# - sometimes two objects refrence each other, adding complexity and overheads
#
# 5) Performance issues with large data
#
# - python use libraries and data data units that perform many functions which can be used to perform execution in turn consuming a large amount of data.

# %% [markdown]
# **Question 4:Write a Python program that reads from one file and writes its content to
# another file.**

# %% [markdown]
# **Question 3:Write a Python program that logs an error message to a log file when a
# division by zero exception occurs.**

# %%
import logging
logging.basicConfig(
    filename='error.log',
    level=logging.ERROR
)
try:
  result=10/0

except ZeroDivisionError:
  logging.error("Division by Zero occured")
# Out:
# ERROR:root:Division by Zero occured

# %% [markdown]
# **Question 5: Write a program that handles both IndexError and KeyError using a
# try-except block.**

# %%
students=['Jason','Renee','Ab']
marks={'Jason':86,'Renee':90}

try:
  print(students[5])
  print(marks['David'])

except IndexError:
  print('Index Error: index out of range')

except KeyError:
  print('KeyError:key not found in dict')
# Out:
# Index Error: index out of range

# %% [markdown]
# **Question 6: What are the differences between NumPy arrays and Python lists?**

# %% [markdown]
# -numpyarrays stores elements of one data type while python list stores dirrefent data types
#
# -numpyarrays are faster and optimised for math operations while python list are slower with mathematical operations
#
# -numpy arrays are memory efficient while python lists use more memory
#
# -numpyarray supports element wise arithmetic operations while python lists do not support element wise arithmetic directly
#
# -numpy array need numpy() libraries to be imported while python lists are just avilable by default

# %% [markdown]
# **Question 7:Explain the difference between apply() and map() in Pandas.**

# %% [markdown]
# _apply() transforms values across 2 and 3 dimensions or DataFrames while Map() only transforms values in a single series_1 dimesnsions
#
# _apply() applies a function to rows, columns or individual elemnts while map() applies a function to each element individually
#
# _apply() is used for complex operations and calculations while map() is used for a simple transformation
#
# _apply() can operate on an entire DataFrame while map() cannot operate an entire DataFrame

# %% [markdown]
# **Question 8: Create a histogram using Seaborn to visualize a distribution.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data=[12,12,12,20,22,25,25,28,32,32,32,32]

sns.histplot(data)
plt.title('Histogram')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Question 9: Use Pandas to load a CSV file and display its first 5 rows.**

# %%
import pandas as pd
df=pd.read_csv('/content/indian_cities_population.csv')
df.head()
# Out:
#         City        State  Population_Millions  Male_Percentage  \
# 0     Mumbai  Maharashtra                 20.7               52
# 1      Delhi        Delhi                 32.9               53
# 2  Bengaluru    Karnataka                 13.6               52
# 3  Hyderabad    Telangana                 11.1               51
# 4    Chennai   Tamil Nadu                 11.2               50
#
#    Female_Percentage
# 0                 48
# 1                 47
# 2                 48
# 3                 49
# 4                 50

# %% [markdown]
# **Question 10: Calculate the correlation matrix using Seaborn and visualize it with a
# heatmap.**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    "Math": [80, 75, 90, 85, 70],
    "Science": [78, 72, 88, 84, 69],
    "English": [85, 80, 92, 86, 75]
}

df = pd.DataFrame(data)

correlation = df.corr()

sns.heatmap(correlation, annot=True)

plt.title("Correlation Matrix")
plt.show()
